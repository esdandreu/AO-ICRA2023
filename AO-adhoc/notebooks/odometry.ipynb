# %% [markdown]
# This notebook is part of Andreu's (esdandreu@gmail.com) Master Thesis work at
# Keio University.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AcousticOdometry/AO/blob/main/notebooks/odometry.ipynb)

# %% [markdown]
# # Setup
#
# This section will take care of installing the necessary packages as well as
# configuring some environment variables.

# %% [markdown]
# ## Colab
#
# Assess wether the notebook is being executed in [Google
# Colab](https://colab.research.google.com/) and if so, set up the software
# needed in Colab runtime.

# %%
# %%capture
try:
    from google import colab
    COLAB_RUNTIME = True
    # %pip install runstats
    colab.drive.mount('/content/drive')
except ImportError:
    COLAB_RUNTIME = False

# %% [markdown]
# ## Packages

# %%
import os
import re
import yaml
import torch
import cpuinfo  # pip install py-cpuinfo
import numpy as np
import pandas as pd

from time import time_ns
from pathlib import Path
from functools import partial
from tqdm.notebook import tqdm  # pip install tqdm
from runstats import Statistics  # pip install runstats
from typing import Dict, List, Tuple, Callable, Optional, Union

from matplotlib import pyplot as plt
from matplotlib import rcParams, rc_context

if not COLAB_RUNTIME:
    # Workaround: in some notebook editors, `rcParams` modifications won't take
    # effect until something is plotted
    plt.figure()
    plt.close()
    rcParams["figure.figsize"] = (15, 5)
    rcParams["figure.constrained_layout.use"] = True
    rcParams["figure.autolayout"] = False
    rcParams["savefig.dpi"] = 300


def savefig(fig: plt.Figure, *args, bbox_inches='tight', **kwargs):
    bbox_extra_artists = [
        *fig.legends,
        ]
    if fig.subfigs:
        for subfig in fig.subfigs:
            if subfig.legends:
                bbox_extra_artists.extend(list(subfig.legends))
    if fig._suptitle:
        bbox_extra_artists.append(fig._suptitle)
    return fig.savefig(
        *args,
        **kwargs,
        bbox_extra_artists=tuple(bbox_extra_artists),
        bbox_inches=bbox_inches,
        )

# %% [markdown]
# ### AO
#
# Setup Acoustic Odometry python package. If this notebook is being executed in
# [Colab](#colab), the package will be installed from Github. Because of this, a
# Github [personal access
# token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token)
# is needed for the installation.
#
# If the notebook is not running on Colab and the package is not already
# installed, installation instructions will be prompted.

# %%
if COLAB_RUNTIME:
    import subprocess
    import requests
    import sys
    import os
    #@markdown Use a [GitHub Personal Access Token](https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/creating-a-personal-access-token)
    GITHUB_TOKEN = ''  #@param {type:"string"}
    auth = requests.auth.HTTPBasicAuth('', GITHUB_TOKEN)
    response = requests.get(
        "https://api.github.com/repos/AcousticOdometry/AO/releases/latest",
        auth=auth
        )
    try:
        response.raise_for_status()
    except requests.HTTPError as e:
        raise RuntimeError(
            'Check GITHUB_TOKEN is a Personal Access Token with repo access'
            )
    headers = {'Accept': 'application/octet-stream'}
    for asset in response.json()['assets']:
        r = requests.get(
            asset['url'], auth=auth, allow_redirects=True, headers=headers
            )
        r.raise_for_status()
        wheel_name = asset['name']
        with open(wheel_name, 'wb') as f:
            f.write(r.content)
        try:
            result = subprocess.check_output([
                sys.executable, '-m', 'pip', 'install', wheel_name
                ])
            print(f'Installed {wheel_name}')
            break
        except subprocess.CalledProcessError as e:
            pass
        finally:
            os.remove(wheel_name)
    import ao
else:
    try:
        import ao
    except ImportError:
        raise ImportError(
            "Acoustic Odometry python extension is not installed. Check "
            r"https://github.com/AcousticOdometry/AO#readme"
            " for detailed instructions."
            )

# %% [markdown]
# # Odometry

# %%
if COLAB_RUNTIME:
    # @markdown Check where is the experiment folder situated in your drive folder.
    # @markdown Remember that if you have been shared the folder, you can
    # @markdown [add a shortcut to your drive](https://support.google.com/drive/answer/9700156?hl=en&co=GENIE.Platform%3DDesktop)
    # @markdown in order to make it available in google colab.
    experiment = "/content/drive/MyDrive/VAO_WheelTestBed-Experiment-2"  #@param {type:"string"}
    EXPERIMENT_FOLDER = Path(experiment)
    if not EXPERIMENT_FOLDER.is_dir():
        raise RuntimeError(f'Invalid experiment folder {EXPERIMENT_FOLDER}')
else:
    EXPERIMENT_FOLDER = ao.dataset.utils.get_folder(
        env='WHEELTESTBED_EXPERIMENT2'
        )
MODELS_FOLDER = EXPERIMENT_FOLDER / 'models'
EVALUATION_FOLDER = EXPERIMENT_FOLDER / 'evaluation-recordings'

# %% [markdown]
# ## Generate recording ground truth
#
# The recording is composed by audio files from several devices that span for the
# whole experiment and several wheel testbed control files that span for certain
# parts of the experiment. In this section we combine the control files in order
# to generate a unique ground truth for the whole recording.

# %%
# Get the first evaluation recording found in the folder
for folder in EVALUATION_FOLDER.iterdir():
    if folder.is_dir():
        recording = folder
        break
else:
    raise RuntimeError(f'No evaluation recording found in {EVALUATION_FOLDER}')

# %%
def get_recording_bounds(recording: Path) -> Tuple[float, float]:
    """Get the start and end timestamp of a recording from its audio files

    Args:
        recording (Path): Path to a recording folder with wheel testbed
            control files, audio files and their corresponding configuration
            files

    Returns:
        Tuple[float, float]: start and end timestamps
    """
    start_timestamp = np.Inf
    end_timestamp = 0
    for wav_file in recording.glob('*.wav'):
        config = ao.io.yaml_load(wav_file.with_suffix('.yaml'))
        start_timestamp = min(start_timestamp, config['start_timestamp'])
        end_timestamp = max(end_timestamp, config['end_timestamp'])
    return start_timestamp, end_timestamp


get_recording_bounds(recording=recording)
# Out:
# (1653033646.109341, 1653033821.222812)

# %%
def generate_recording_ground_truth(
        recording: Path, wheel_radius: float = 0.1
    ) -> pd.DataFrame:
    """Generates the ground truth of an evaluation recording from its control
    files

    Args:
        recording (Path): Path to a recording folder with wheel testbed
            control files, audio files and their corresponding configuration
            files
        wheel_radius (float, optional): Effective radius of the wheel in [m].

    Returns:
        pd.DataFrame: Ground truth of the recording with columns 'X', 'Vx',
            'Vw', 'slip', 'wheel_rotation' and 'timestamp' as index
    """
    start_timestamp, end_timestamp = get_recording_bounds(recording)
    gt = pd.DataFrame(columns=['X', 'Vx', 'Vw', 'wheel_rotation'])
    gt.loc[start_timestamp] = np.zeros(len(gt.columns))
    for control_file in sorted(recording.glob('*.csv')):
        if control_file.stem == 'ground_truth':
            continue
        df = pd.read_csv(
            control_file,
            index_col='timestamp',
            usecols=['timestamp'] + list(gt.columns),
            parse_dates=True,
            )
        df['Vx_from_encoder'] = df['Vw'].apply(np.deg2rad) * wheel_radius
        df['slip'] = (df['Vx_from_encoder'] -
                      df['Vx']) / df[['Vx_from_encoder', 'Vx']].max(axis=1)
        df.drop('Vx_from_encoder', axis=1, inplace=True)
        # Accumulable columns
        for col in ['X', 'wheel_rotation']:
            df[col] = df[col] + gt[col].iloc[-1]
        # Wheel stops at the end of the movement, assume stopped after 100 ms
        df.loc[df.tail(1).index.item() + 0.1] = df.iloc[-1].copy()
        # Update the first and last row with null velocities
        for col in ['Vx', 'Vw', 'slip']:
            col_index = gt.columns.get_loc(col)
            df.iloc[0, col_index] = 0
            df.iloc[-1, col_index] = 0
        # After each control the wheel stops
        gt = pd.concat([gt, df])
    gt.loc[end_timestamp] = gt.iloc[-1].copy()
    for col in ['Vx', 'Vw', 'slip']:
        col_index = gt.columns.get_loc(col)
        gt.iloc[-1, col_index] = 0
    gt.loc[:, 'X'] /= 1000  # [mm] -> [m]
    gt['tx'] = gt['X'].diff()
    gt.iloc[0, gt.columns.get_loc('tx')] = 0
    return gt

# %%
def get_recording_ground_truth(
        recording: Path,
        wheel_radius: float = 0.1,
        force_generation: bool = False
    ) -> pd.DataFrame:
    """Gets the ground truth corresponding to a recording

    Args:
        recording (Path): Path to a recording folder with wheel testbed
            control files, audio files and their corresponding configuration
            files
        wheel_radius (float, optional): Effective radius of the wheel in [m].
        force_generation (bool, optional): Force generation instead of loading
            from file. Defaults to False.

    Returns:
        pd.DataFrame: Ground truth of the recording with columns 'X', 'Vx',
        'Vw', 'slip', 'wheel_rotation'
    """
    ground_truth_path = recording / 'ground_truth.csv'
    if not force_generation and ground_truth_path.exists():
        gt = pd.read_csv(ground_truth_path, index_col='timestamp')
    else:
        gt = generate_recording_ground_truth(recording, wheel_radius)
        gt.to_csv(ground_truth_path, index_label='timestamp')
    # ! Manually aligned timestamps
    # Audio recording timestamps and wheel testbed control are not properly
    # synchronized. Which is a problem because without the manual alignment
    # Acoustic Odometry seems to predict movements way before they happen.
    # ! Hacky, but fair to add the same value to all recordings from the same
    # day. Better synchronized evaluation recordings should be used in the
    # future
    if recording.name.startswith('06') or recording.name.startswith('07'):
        gt.index -= 4
    else:
        gt.index -= 2
    return gt


ground_truth = get_recording_ground_truth(recording=recording)
ao.plot.odometry(ground_truth)
ground_truth.head()
# Out:
#                     X      Vx       Vw     slip  wheel_rotation       tx
# timestamp
# 1.653034e+09  0.00000  0.0000   0.0000  0.00000        0.000000  0.00000
# 1.653034e+09  0.00000  0.0000   0.0000  0.00000        0.002397  0.00000
# 1.653034e+09  0.00011  0.0011   7.0113  0.91011        0.703520  0.00011
# 1.653034e+09  0.00129  0.0118   9.8078  0.31066        1.684300  0.00118
# 1.653034e+09  0.00371  0.0242  10.1710 -0.36320        2.701400  0.00242

# %% [markdown]
# ### Wheel Odometry

# %%
def get_recording_wheel_odometry(
        recording: Path, wheel_radius: float
    ) -> pd.DataFrame:
    return ao.evaluate.generate_wheel_odometry(
        get_recording_ground_truth(recording)['Vw'], wheel_radius=wheel_radius
        )


wheel_odom = get_recording_wheel_odometry(recording, 0.1)
_ = ao.plot.odometry(wheel_odom)

# %% [markdown]
# ### Visual Odometry

# %%
def get_file_visual_odometry(bag_path: Path, method: str) -> pd.DataFrame:
    odometry_path = bag_path.parent / 'VO' / method / bag_path.with_suffix(
        '.txt'
        ).name
    vo = pd.read_csv(
        odometry_path,
        header=None,
        names=['timestamp', 'tx', 'ty', 'tz', 'qx', 'qy', 'qz', 'qw'],
        index_col='timestamp',
        sep=' ',
        )
    # TODO need to align it with the ground truth
    vo['tx'] /= 1000  # [mm] -> [m]
    vo['X'] = vo['tx'].cumsum()
    vo['Vx'] = vo['tx'] / vo.index.to_series().diff()
    return vo


def get_T265_tracking(
    bag_path: Path,
    method: str,
    config: Optional[dict] = None,
    ) -> pd.DataFrame:
    data_path = bag_path.parent / 'VO' / method / bag_path.with_suffix(
        '.txt'
        ).name
    vo = pd.read_csv(
        data_path,
        header=None,
        names=['timestamp', 'Y', 'Z', '-X', 'qy', 'qz', '-qx', 'qw'],
        index_col='timestamp',
        sep=' ',
        )
    if config is None:
        config = ao.io.yaml_load(bag_path.with_suffix('.yaml'))
    start_timestamp = config['start_timestamp']
    vo.index += start_timestamp
    vo['X'] = -vo['-X']
    vo['tx'] = vo['X'].diff()
    vo['Vx'] = vo['tx'] / vo.index.to_series().diff()
    # ! Manually aligned timestamps
    if (
        bag_path.parent.name.startswith('06')
        or bag_path.parent.name.startswith('07')
        ):
        vo.index -= 4
    else:
        vo.index -= 2
    return vo


def get_recording_visual_odometry(
        recording: Path, method: str
    ) -> pd.DataFrame:
    # TODO check which recording uses a T265 camera
    for bag_path in sorted(recording.glob('*.bag')):
        config = ao.io.yaml_load(bag_path.with_suffix('.yaml'))
        if 'T265' in method and 'T265' in config['name']:
            return get_T265_tracking(bag_path, method, config)
        elif 'T265' not in method and 'T265' not in config['name']:
            return get_file_visual_odometry(bag_path, method)
    else:
        raise RuntimeError(
            f"Recording {recording} has no bag file appropriate for {method}"
            )


visual_odom = get_recording_visual_odometry(
    EVALUATION_FOLDER / '06_w12', method='orbslam2_rgbd'
    )
ao.plot.odometry(visual_odom)
visual_odom.head()
# Out:
#                         tx            ty            tz   qx   qy   qz   qw  \
# timestamp
# 1.655292e+09  0.000000e+00  0.000000e+00  0.000000e+00  0.0  0.0  0.0  1.0
# 1.655292e+09 -7.848953e-43 -9.727674e-41  1.635526e-40  0.0  0.0  0.0  1.0
# 1.655292e+09 -8.828180e-47 -8.407791e-45  3.363116e-44  0.0  0.0  0.0  1.0
# 1.655292e+09  1.123079e-41  1.494155e-38 -1.368324e-38  0.0  0.0  0.0  1.0
# 1.655292e+09 -1.336166e-42  8.702134e-40 -1.424805e-39  0.0  0.0  0.0  1.0
#
#                          X            Vx
# timestamp
# 1.655292e+09  0.000000e+00           NaN
# 1.655292e+09 -7.848953e-43 -1.069662e-41
# 1.655292e+09 -7.849836e-43 -1.214111e-45
# 1.655292e+09  1.044581e-41  1.559702e-40
# 1.655292e+09  9.109640e-42 -1.875774e-41

# %%
r = EVALUATION_FOLDER / '07_VO-challenge'
_ = ao.plot.odometry_comparison([
    (get_recording_ground_truth(r), 'ground truth'),
    (
        get_recording_visual_odometry(r, method='realsense_T265'),
        'visual odom',
        ),
    ])

# %% [markdown]
# ## Generate odometry with model

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using {DEVICE} device")
# Out:
# Using cuda device

# %%
from platform import architecture


def _get_Vx_from_regression(prediction: torch.tensor) -> float:
    return (prediction.item()) / 10


def _get_Vx_from_classification(
        prediction: torch.tensor, centers: List[float]
    ):
    return centers[int(prediction.argmax(1).sum().item())]


def _get_Vx_from_informed_classification(
        prediction: Tuple[torch.tensor], w_centers: List[float],
        s_centers: List[float], wheel_radius: float
    ):
    w, s = prediction
    w = w_centers[int(w.argmax(dim=1).sum().item())]
    s = s_centers[int(s.argmax(dim=1).sum().item())]
    if s > 0:
        return w * wheel_radius * (1 - s)
    return w * wheel_radius / (1 + s)


def _get_Vx_from_ordinal_classification(
        prediction: torch.tensor, centers: List[float]
    ):
    label = (prediction > 0.5).cumprod(axis=1).sum(axis=1) - 1
    return centers[int(max(label.item(), 0))]


def model_factory(
    name: str,
    dataset_config: Optional[dict] = None,
    config: Optional[dict] = None,
    sample_rate: int = 44100,
    models_folder: Path = MODELS_FOLDER,
    device=DEVICE,
    ) -> ao.AO:
    model_folder = models_folder / name
    if dataset_config is None:
        dataset_config = ao.io.yaml_load(model_folder / 'dataset.yaml')
    # Build extractors
    extractors = []
    for extractor in dataset_config['extractors']:
        # Get the extractor class
        try:
            extractor_class = getattr(ao.extractor, extractor['class'])
        except AttributeError as e:
            raise RuntimeError(
                f"Extractor `{extractor['class']}` not found: {e}"
                )
        # Get the extractor keyword arguments
        _kwargs = {}
        for key, arg in extractor['kwargs'].items():
            # Check if the argument is a function source
            if isinstance(arg, str):
                match = re.search(r"def (?P<function_name>.*)\(", arg)
                if match:
                    # If it is function source, execute it and get the function
                    # handle
                    # ! This code is unsafe, it could be tricked by a
                    # ! maliciously built config file
                    exec(arg)
                    _kwargs[key] = eval(match.group('function_name'))
                    continue
            _kwargs[key] = arg
        extractors.append(
            extractor_class(
                num_samples=int(
                    dataset_config['frame_duration'] * sample_rate / 1000
                    ),
                num_features=dataset_config['frame_features'],
                sample_rate=sample_rate,
                **_kwargs
                )
            )
    model = ao.AO(
        name=name,
        model_path=model_folder / 'model.pt',
        extractors=extractors,
        num_frames=dataset_config['segment_frames'],
        device=device,
        )
    if config is None:
        with open(model_folder / 'model.yaml') as f:
            config = yaml.full_load(f)
    if config['task'] == 'classification':
        if config['architecture'] == 'UnnormalizedInformedCNN':
            model.get_Vx = partial(
                _get_Vx_from_informed_classification,
                w_centers=model.model.w_centers,
                s_centers=model.model.s_centers,
                wheel_radius=model.model.wheel_radius,
                )
        else:
            model.get_Vx = partial(
                _get_Vx_from_classification,
                centers=model.model.centers,
                )
    elif config['task'] == 'ordinal_classification':
        model.get_Vx = partial(
            _get_Vx_from_ordinal_classification, centers=model.model.centers
            )
    elif config['task'] == 'regression':
        model.get_Vx = _get_Vx_from_regression
    else:
        raise RuntimeError(f"Task {model['task']} not supported")
    return model


for f in MODELS_FOLDER.iterdir():
    if (f / 'model.pt').exists():
        model = model_factory(f.name)
        # model = f.name
        break

# %%
def generate_acoustic_odometry(
    wav_file: Path,
    model: ao.AO,
    pbar: Optional[tqdm] = None,
    *,
    return_config: bool = False,
    ) -> pd.DataFrame:
    """Generates odometry from a wav file using the provided model

    Args:
        wav_file (Path): Audio recording in wav format
        model (ao.AO): Acoustic Odometry model
        pbar (Optional[tqdm]): Progress bar to display. If False, no progress
            bar is displayed.
        return_config (bool, optional): Whether to return the configuration
            dictionary with the odometry data. Defaults to False.

    Returns:
        pd.DataFrame: Odometry data with columns 'Vx', 'tx' and 'X'. If
            `return_config` is True, the configuration dictionary is also
            returned. 
    """
    wav_data, _ = ao.io.audio_read(wav_file)
    config = ao.io.yaml_load(wav_file.with_suffix('.yaml'))
    start = config['start_timestamp']
    step = model.num_samples / model.sample_rate
    frames = ao.dataset.audio._frames(wav_data, model.num_samples)
    timestamps = np.linspace(start, start + len(frames) * step, len(frames))
    Vx = np.empty(len(frames))
    if pbar is False:
        for i, frame in enumerate(frames):
            prediction = model.predict(frames)
            Vx[i] = model.get_Vx(prediction)
    else:
        if pbar is None:
            pbar = tqdm(unit='frames')
        pbar.set_description(f"{wav_file.parent.name}/{wav_file.stem}")
        pbar.reset(total=len(frames))
        for i, frame in enumerate(frames):
            prediction = model.predict(frames)
            Vx[i] = model.get_Vx(prediction)
            pbar.update()
    # Compute X translations and cumulative X position
    Vx = pd.Series(Vx, index=timestamps)
    odom = pd.concat([Vx, Vx.index.to_series().diff() * Vx], axis=1)
    odom.columns = ['Vx', 'tx']
    odom.iloc[0, :] = 0
    odom['X'] = odom['tx'].cumsum()
    if return_config:
        return odom, config
    return odom

# %%
def get_file_acoustic_odometry(
    model: ao.AO,
    wav_file: Path,
    pbar: Optional[tqdm] = None,
    force_generation: bool = False,
    *,
    return_config: bool = False,
    ) -> pd.DataFrame:
    """Gets the odometry data corresponding to a wav file and model

    Args:
        model (ao.AO): Acoustic Odometry model.
        wav_file (Path): Audio recording in wav format.
        pbar (Optional[tqdm]): Progress bar to display. If False, no progress
            bar is displayed.
        force_generation (bool, optional): Force generation instead of loading
            from file. Defaults to False.
        return_config (bool, optional): Whether to return the configuration
            dictionary with the odometry data. Defaults to False.

    Returns:
        pd.DataFrame: Odometry data with columns 'Vx', 'tx' and 'X' and a name
            attribute that corresponds to the stem of the audio file. If
            `return_config` is True, the configuration dictionary is also
            returned. 
    """
    odometry_path = wav_file.parent / 'AO' / str(model) / wav_file.with_suffix(
        '.odometry.csv'
        ).name
    if not force_generation and odometry_path.exists():
        odom = pd.read_csv(odometry_path, index_col='timestamp')
        odom.name = wav_file.stem
        if return_config:
            config = ao.io.yaml_load(wav_file.with_suffix('.yaml'))
            return odom, config
        return odom
    odometry_path.parent.mkdir(exist_ok=True, parents=True)
    odom, config = generate_acoustic_odometry(
        wav_file, model, pbar=pbar, return_config=True
        )
    odom.to_csv(odometry_path, index_label='timestamp')
    odom.name = wav_file.stem
    if return_config:
        return odom, config
    return odom


acoustic_odom = get_file_acoustic_odometry(
    model,
    wav_file=recording / f'microphone0.wav',
    )
ao.plot.odometry_comparison([(ground_truth, 'ground truth'),
                             (acoustic_odom, 'acoustic odometry'),
                             (wheel_odom, 'wheel odometry')])
acoustic_odom.head()
# Out:
#                Vx   tx    X
# timestamp
# 1.653034e+09  0.0  0.0  0.0
# 1.653034e+09  0.0  0.0  0.0
# 1.653034e+09  0.0  0.0  0.0
# 1.653034e+09  0.0  0.0  0.0
# 1.653034e+09  0.0  0.0  0.0

# %%
def get_recording_acoustic_odometry(
    model: ao.AO,
    recording: Path,
    pbars: Optional[Dict[str, tqdm]] = None,
    force_generation: bool = False,
    *,
    return_config: bool = False,
    ) -> List[pd.DataFrame]:
    files = sorted(recording.glob('*.wav'))
    result = []
    if pbars is False:
        for wav_file in files:
            result.append(
                get_file_acoustic_odometry(
                    model,
                    wav_file,
                    pbar=False,
                    force_generation=force_generation,
                    return_config=return_config
                    )
                )
        return result
    if not pbars:
        pbars = {
            'files': tqdm(unit='files'),
            'frames': tqdm(unit='frames'),
            }
    pbars['files'].reset(total=len(files))
    for wav_file in files:
        pbars['files'].set_description(wav_file.name)
        result.append(
            get_file_acoustic_odometry(
                model,
                wav_file,
                pbar=pbars['frames'],
                force_generation=force_generation,
                return_config=return_config
                )
            )
        pbars['files'].update()
    return result

# %%
def plot_recording_odometry(
    recording: Path,
    acoustic_odometry_models: List[ao.AO] = [],
    visual_odometry_methods: List[str] = [],
    wheel_odometry_with_radius: Optional[float] = None,
    *,
    acoustic_odometry_filter: Callable[[str, str],
                                       bool] = lambda model, device: True,
    fig: Optional[plt.Figure] = None,
    ax_speed: Optional[plt.Axes] = None,
    ax_position: Optional[plt.Axes] = None,
    show_progress: bool = True,
    show_legend: bool = True,
    ) -> Tuple[plt.Figure, List[plt.Axes]]:
    # Plot ground truth
    ground_truth = get_recording_ground_truth(recording)
    plots = [(ground_truth, 'ground truth')]
    # Plot acoustic odometry
    if show_progress:
        pbars = {
            'models': tqdm(unit='models'),
            'files': tqdm(unit='files'),
            'frames': tqdm(unit='frames'),
            }
        pbars['models'].reset(total=len(acoustic_odometry_models))
    else:
        pbars = False
    for model in acoustic_odometry_models:
        if pbars:
            pbars['models'].set_description(str(model))
        plots.extend([(odom, f"AO {str(model)} {config['name']}")
                      for odom, config in get_recording_acoustic_odometry(
                          model, recording, pbars, return_config=True
                          )
                      if acoustic_odometry_filter(str(model), config['name'])])
        if pbars:
            pbars['models'].update()
    # Plot visual odometry
    for method in visual_odometry_methods:
        plots.append(
            (get_recording_visual_odometry(recording, method), f"VO {method}")
            )
    # Plot wheel odometry
    if wheel_odometry_with_radius:
        plots.append((
            get_recording_wheel_odometry(
                recording, wheel_odometry_with_radius
                ), 'wheel odometry'
            ))
    if ax_speed or ax_position:
        pass
    elif fig:
        ax_speed, ax_position = fig.subplots(1, 2)
    else:
        fig, (ax_speed, ax_position) = plt.subplots(1, 2)
    return ao.plot.odometry_comparison(
        plots,
        ax_speed=ax_speed,
        ax_position=ax_position,
        suptitle=recording.name,
        show_legend=show_legend,
        )


_ = plot_recording_odometry(
    recording,
    acoustic_odometry_models=[model],
    # acoustic_odometry_filter=(lambda model, device: 'VideoMic' in device),
    wheel_odometry_with_radius=0.1
    )
# Out:
# 0models [00:00, ?models/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %% [markdown]
# ## Evaluate the results

# %%
def plot_recording_evaluation(
    recording: Path,
    acoustic_odometry_models: List[ao.AO] = [],
    visual_odometry_methods: List[str] = [],
    wheel_odometry_with_radius: Optional[float] = None,
    *,
    acoustic_odometry_filter: Callable[[str, str],
                                       bool] = lambda model, device: True,
    fig: Optional[plt.Figure] = None,
    show_legend: bool = True,
    **evaluate_kwargs,
    ) -> Tuple[plt.Figure, List[plt.Axes]]:
    # Get ground truth
    ground_truth = get_recording_ground_truth(recording)
    plots = []
    # Plot acoustic odometry
    for model in acoustic_odometry_models:
        plots.extend([(odom, f"AO {str(model)} {config['name']}")
                      for odom, config in get_recording_acoustic_odometry(
                          model, recording, pbars=False, return_config=True
                          )
                      if acoustic_odometry_filter(str(model), config['name'])])
    # Plot visual odometry
    for method in visual_odometry_methods:
        plots.append(
            (get_recording_visual_odometry(recording, method), f"VO {method}")
            )
    # Plot wheel odometry
    if wheel_odometry_with_radius:
        plots.append((
            get_recording_wheel_odometry(
                recording, wheel_odometry_with_radius
                ), 'wheel odometry'
            ))
    return ao.plot.evaluation_comparison(
        plots,
        ground_truth,
        evaluate_kwargs=evaluate_kwargs,
        fig=fig,
        suptitle=recording.name,
        show_legend=show_legend,
        )


_ = plot_recording_evaluation(
    recording,
    acoustic_odometry_models=[model],
    acoustic_odometry_filter=(lambda model, device: 'VideoMic' in device),
    visual_odometry_methods=['orbslam2_rgbd'],
    )

# %%
@rc_context({'figure.figsize': (10, 10)})
def plot_recording(
    recording: Path,
    acoustic_odometry_models: List[ao.AO] = [],
    visual_odometry_methods: List[str] = [],
    wheel_odometry_with_radius: Optional[float] = None,
    *,
    fig: Optional[plt.Figure] = None,
    acoustic_odometry_filter: Callable[[str, str],
                                       bool] = lambda model, device: True,
    **evaluate_kwargs,
    ) -> plt.Figure:
    if not fig:
        fig = plt.figure()
    subfigs = fig.subfigures(2, 1)
    _, odom_axes = plot_recording_odometry(
        recording,
        acoustic_odometry_models=acoustic_odometry_models,
        visual_odometry_methods=visual_odometry_methods,
        wheel_odometry_with_radius=wheel_odometry_with_radius,
        acoustic_odometry_filter=acoustic_odometry_filter,
        fig=subfigs[0],
        show_legend=False,
        )
    subfigs[0].suptitle('Odometry')
    _, eval_axes = plot_recording_evaluation(
        recording,
        acoustic_odometry_models=acoustic_odometry_models,
        visual_odometry_methods=visual_odometry_methods,
        wheel_odometry_with_radius=wheel_odometry_with_radius,
        acoustic_odometry_filter=acoustic_odometry_filter,
        fig=subfigs[1],
        show_legend=False,
        **evaluate_kwargs,
        )
    subfigs[1].suptitle('Evaluation')
    fig.suptitle(recording.name)
    fig.legend(
        *odom_axes[1].get_legend_handles_labels(),
        bbox_to_anchor=(0.5, 0),
        loc='upper center'
        )
    return fig


_ = plot_recording(recording, acoustic_odometry_models=[model])
# Out:
# 0models [00:00, ?models/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %%
recordings = sorted([f for f in EVALUATION_FOLDER.iterdir() if f.is_dir()])


@rc_context({'figure.figsize': (7.5, 8)})
def plot_acoustic_odometry_evaluation(
    recordings: List[Path] = recordings,
    models: List[ao.AO] = [],
    metrics: Dict[str, str] = {
        'RPE': 'Mean',
        'APPE': 'Final',
        },
    *,
    filter: Callable[[str, str], bool] = lambda model, device: True,
    fig: Optional[plt.Figure] = None,
    **evaluate_kwargs,
    ) -> Tuple[plt.Figure, np.ndarray]:
    pbars = {
        'recordings': tqdm(unit='recording'),
        'models': tqdm(unit='model'),
        'files': tqdm(unit='files'),
        'frames': tqdm(unit='frames'),
        }
    if not fig:
        fig = plt.figure()
    axs = fig.subplots(
        len(recordings),
        len(metrics),
        sharey=True,
        sharex='col',
        squeeze=False,
        )
    for ax in axs.ravel():
        ax.grid(True, which='both')
        ax.set_xscale('log')
    averages = {
        str(model): {key: 0
                     for key in metrics.keys()}
        for model in models
        }
    pbars['recordings'].reset(total=len(recordings))
    for ax_row, recording in enumerate(recordings):
        pbars['recordings'].set_description(recording.name)
        ground_truth = get_recording_ground_truth(recording)
        pbars['models'].reset(total=len(models))
        for m_idx, model in enumerate(models):
            pbars['models'].set_description(str(model))
            evaluation = pd.DataFrame()
            for odom, config in get_recording_acoustic_odometry(
                model, recording, pbars=pbars, return_config=True
                ):
                if not filter(str(model), config['name']):
                    continue
                _evaluation = ao.evaluate.odometry(
                    odom, ground_truth, **evaluate_kwargs
                    )
                for column, operation in metrics.items():
                    if operation.lower() == 'mean':
                        operator = lambda x: x.mean()
                    elif operation.lower() == 'final':
                        operator = lambda x: x.iloc[-1]
                    else:
                        raise ValueError(f"Unknown operation {operation}")
                    evaluation.loc[config['name'],
                                   column] = operator(_evaluation[column])
                    # ! A bit hacky but it is only a plot. Good is good enough
                    _evaluation.attrs['description'][column] = (
                        operation + ' ' +
                        _evaluation.attrs['description'][column]
                        )
            for ax_col, column in enumerate(evaluation.columns):
                ax = axs[ax_row, ax_col]
                if ax_row == 0:
                    ax.set_title(_evaluation.attrs['description'][column])
                plot = ax.scatter(
                    evaluation[column].values,
                    evaluation[column].index,
                    label=str(model),
                    marker=(3, 2, m_idx / len(models) * 180),
                    alpha=0.8,
                    )
                if ax_row == len(recordings) - 1:
                    ax.set_xlabel(
                        f"Error [{_evaluation.attrs['unit'][column]}]"
                        )
                # Plot model recording average
                _mean = evaluation[column].values.mean()
                ax.axvline(
                    _mean,
                    ls='--',
                    color=plot.get_edgecolor(),
                    )
                averages[str(model)][column] += _mean / len(recordings)
            pbars['models'].update()
        axs[ax_row, 0].set_ylabel(recording.name)
        pbars['recordings'].update()
    handles, labels = axs[0, 0].get_legend_handles_labels()
    # Add averages to legend
    label_size = max([len(label) for label in labels])
    fig.legend(
        handles, [
            l.ljust(label_size + 1) + '; '.join([
                f"{k}: {v:.2e} [{_evaluation.attrs['unit'][k]}]"
                for k, v in averages[l].items()
                ]) for l in labels
            ],
        bbox_to_anchor=(0.5, 0),
        loc='upper center',
        prop={'family': 'monospace'}
        )
    return fig, axs


_ = plot_acoustic_odometry_evaluation(
    recordings=[r for r in recordings if not '_snr' in r.name], models=[model]
    )
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %% [markdown]
# ## Benchmark execution time

# %%
# TODO generate benchmark


def generate_benchmark(
    model_name: str,
    with_device: torch.device,
    models_folder: Path = MODELS_FOLDER,
    wav_file: Path = EVALUATION_FOLDER / '01_contact' / 'microphone0.wav',
    iterations: int = 1000,
    ) -> None:
    wav_data, sample_rate = ao.io.audio_read(wav_file)
    model = model_factory(
        model_name, device=with_device, sample_rate=sample_rate
        )
    benchmark = {
        'device': {
            'type': with_device.type
            },
        'recording': wav_file.parent.name,
        'file': wav_file.name,
        'unit': 'ns',
        'time': {},
        }
    if benchmark['device']['type'] == 'cuda':
        benchmark['device']['name'] = torch.cuda.get_device_name(
            torch.cuda.current_device()
            )
    elif benchmark['device']['type'] == 'cpu':
        benchmark['device'].update(cpuinfo.get_cpu_info())
        benchmark['device']['name'] = benchmark['device']['brand_raw']
    else:
        raise ValueError(f"Unknown device type {benchmark['device']['type']}")
    # Initialize running statistics
    stats = {
        'load': Statistics(),
        'extract': Statistics(),
        'predict': Statistics(),
        'label': Statistics(),
        }
    for i in tqdm(
        range(iterations), desc=f"Benchmark {model_name} {with_device.type}"
        ):
        # Load audio
        start = time_ns()
        try:
            samples = wav_data[:, i:i + model.num_samples]
        except IndexError:
            break
        stats['load'].push(time_ns() - start)
        # Extract
        start = time_ns()
        model.update(samples)
        stats['extract'].push(time_ns() - start)
        # Predict
        start = time_ns()
        prediction = model.predict()
        stats['predict'].push(time_ns() - start)
        # Label
        start = time_ns()
        Vx = model.get_Vx(prediction)
        stats['label'].push(time_ns() - start)
    else:
        i += 1
    benchmark['iterations'] = i
    total_mean = 0
    total_variance = 0
    for name, stat in stats.items():
        benchmark['time'][name] = {
            'mean': stat.mean(),
            'stddev': stat.stddev()
            }
        total_mean += stat.mean()
        total_variance += stat.variance()
    benchmark['time']['total'] = {
        'mean': total_mean,
        'stddev': np.sqrt(total_variance).item()
        }
    return benchmark


generate_benchmark('base', torch.device('cpu'), iterations=10)
# Out:
# Benchmark base cpu:   0%|          | 0/10 [00:00<?, ?it/s]
# {'device': {'type': 'cpu',
#   'python_version': '3.8.10.final.0 (64 bit)',
#   'cpuinfo_version': [8, 0, 0],
#   'cpuinfo_version_string': '8.0.0',
#   'arch': 'X86_64',
#   'bits': 64,
#   'count': 12,
#   'arch_string_raw': 'AMD64',
#   'vendor_id_raw': 'GenuineIntel',
#   'brand_raw': 'Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz',
#   'hz_advertised_friendly': '2.6000 GHz',
#   'hz_actual_friendly': '2.5920 GHz',
#   'hz_advertised': [2600000000, 0],
#   'hz_actual': [2592000000, 0],
#   'l2_cache_size': 1572864,
#   'stepping': 10,
#   'model': 158,
#   'family': 6,
#   'l3_cache_size': 12582912,
#   'flags': ['3dnow',
#    '3dnowprefetch',
#    'abm',
#    'acpi',
#    'adx',
#    'aes',
#    'apic',
#    'avx',
#    'avx2',
#    'bmi1',
#    'bmi2',
#    'clflush',
#    'clflushopt',
#    'cmov',
#    'cx16',
#    'cx8',
#    'de',
#    'dtes64',
#    'dts',
#    'erms',
#    'est',
#    'f16c',
#    'fma',
#    'fpu',
# ...

# %%
def get_benchmark(
        model_name: str,
        with_device: str = 'cpu',
        models_folder: Path = MODELS_FOLDER,
        wav_file: Path = EVALUATION_FOLDER / '01_contact' / 'microphone0.wav',
        iterations: int = int(1E4),
        force_generation: bool = False,
    ):
    device = torch.device(with_device)
    benchmark_path = (
        MODELS_FOLDER / model_name / f"benchmark_{device.type}.yaml"
        )
    if not force_generation and benchmark_path.exists():
        return ao.io.yaml_load(benchmark_path)
    benchmark = generate_benchmark(
        model_name,
        with_device=device,
        models_folder=models_folder,
        wav_file=wav_file,
        iterations=iterations,
        )
    ao.io.yaml_dump(benchmark, benchmark_path)
    return benchmark


get_benchmark('base')
# Out:
# {'device': {'arch': 'X86_64',
#   'arch_string_raw': 'AMD64',
#   'bits': 64,
#   'brand_raw': 'Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz',
#   'count': 12,
#   'cpuinfo_version': [8, 0, 0],
#   'cpuinfo_version_string': '8.0.0',
#   'family': 6,
#   'flags': ['3dnow',
#    '3dnowprefetch',
#    'abm',
#    'acpi',
#    'adx',
#    'aes',
#    'apic',
#    'avx',
#    'avx2',
#    'bmi1',
#    'bmi2',
#    'clflush',
#    'clflushopt',
#    'cmov',
#    'cx16',
#    'cx8',
#    'de',
#    'dtes64',
#    'dts',
#    'erms',
#    'est',
#    'f16c',
#    'fma',
#    'fpu',
#    'fxsr',
#    'ht',
#    'hypervisor',
#    'ia64',
#    'invpcid',
#    'lahf_lm',
#    'mca',
#    'mce',
#    'mmx',
#    'monitor',
#    'movbe',
#    'mpx',
#    'msr',
#    'mtrr',
#    'osxsave',
#    'pae',
#    'pat',
#    'pbe',
#    'pcid',
#    'pclmulqdq',
#    'pdcm',
#    'pge',
#    'pni',
#    'popcnt',
#    'pse',
#    'pse36',
#    'rdrnd',
#    'rdseed',
#    'sep',
#    'serial',
#    'smap',
# ...

# %%
@rc_context({'figure.figsize': (8, 8)})
def plot_acoustic_odometry_benchmark(
    recordings: List[Path] = sorted([
        f for f in EVALUATION_FOLDER.iterdir()
        if f.is_dir() and not '_snr' in f.name
        ]),
    models: List[str] = [],
    performance_metric: Tuple[str, str] = ('RPE', 'Mean'),
    cost_metric: str = 'total',
    *,
    ax: Optional[plt.Axes] = None,
    with_device: str = 'cpu',
    filter: Callable[[str, str], bool] = lambda model, device: True,
    figure_kwargs: dict = {},
    **evaluate_kwargs,
    ) -> Tuple[plt.Figure, np.ndarray]:
    pbars = {
        'recordings': tqdm(unit='recording'),
        'models': tqdm(unit='model'),
        'files': tqdm(unit='files'),
        'frames': tqdm(unit='frames'),
        }
    metric, metric_operation = performance_metric
    if metric_operation == 'Mean':
        metric_fn = lambda x: x.mean()
    elif metric_operation == 'Final':
        metric_fn = lambda x: x.iloc[-1]
    else:
        raise ValueError(f"Unknown metric operation {metric_operation}")
    # Get performance
    performance = {model: 0 for model in models}
    pbars['recordings'].reset(total=len(recordings))
    for recording in recordings:
        pbars['recordings'].set_description(recording.name)
        ground_truth = get_recording_ground_truth(recording)
        pbars['models'].reset(total=len(models))
        for model in models:
            pbars['models'].set_description(str(model))
            recording_performance = 0
            for device_num, (odom, config) in enumerate(
                get_recording_acoustic_odometry(
                    model, recording, pbars=pbars, return_config=True
                    )
                ):
                if not filter(str(model), config['name']):
                    continue
                # Iterate devices
                evaluation = ao.evaluate.odometry(
                    odom, ground_truth, **evaluate_kwargs
                    )
                performance_unit = evaluation.attrs['unit'][metric]
                performance_name = evaluation.attrs['description'][metric]
                recording_performance += metric_fn(evaluation[metric])
            performance[model] += (
                recording_performance / (device_num + 1) / len(recordings)
                )
            pbars['models'].update()
        pbars['recordings'].update()
    cost = {}
    # Get cost
    pbars['models'].reset(total=len(models))
    for model in models:
        pbars['models'].set_description(str(model))
        benchmark = get_benchmark(model, with_device=with_device)
        cost[model] = benchmark['time'][cost_metric]
        pbars['models'].update()
    if not ax:
        fig, ax = plt.subplots(1, 1)
    else:
        fig = ax.get_figure()
    ax.grid(True, which='both')
    ax.set_xscale('log')
    ax.set_yscale('log')
    for model in models:
        ax.errorbar(
            cost[model]['mean'] * 1e-9,
            performance[model],
            xerr=cost[model]['stddev'] * 1e-9,
            label=model,
            fmt='o',
            )
    ax.set_xlabel(
        f"{cost_metric.capitalize()} time on {with_device.upper()} [s]"
        )
    ax.set_ylabel(
        f"{metric_operation} {performance_name} [{performance_unit}]"
        )
    ax.set_title(f"{metric} vs {cost_metric} time on {with_device.upper()}")
    return fig, ax


_ = plot_acoustic_odometry_benchmark(
    models=['base', 'base-XXS'], cost_metric='predict'
    )
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %% [markdown]
# # Results

# %%
RESULTS_PATH = Path(os.getcwd()).parent / 'results'
RESULTS_PATH.mkdir(exist_ok=True)

# %%
import ipywidgets as widgets
from IPython.display import display

w = {
    'recording':
        widgets.Dropdown(
            description='Recording',
            options=[
                f.name for f in sorted(EVALUATION_FOLDER.iterdir())
                if f.is_dir()
                ]
            ),
    'models':
        widgets.SelectMultiple(
            options=[
                f.name for f in sorted(MODELS_FOLDER.iterdir())
                if (f / 'model.pt').exists()
                ],
            description='Models'
            ),
    'devices':
        widgets.SelectMultiple(
            options=[
                'RØDE VideoMic NTG Front', 'RØDE VideoMic NTG Back',
                'RØDE VideoMic NTG Top', 'RØDE smartLav+ wheel axis',
                'RØDE smartLav+ top', 'laptop built-in microphone'
                ],
            description='Devices'
            )
    }
ui = widgets.HBox(list(w.values()))


def explore_recordings(recording, models, devices):
    if not models or not devices:
        return
    _ = plot_recording(
        EVALUATION_FOLDER / recording,
        acoustic_odometry_models=models,
        acoustic_odometry_filter=(lambda model, device: device in devices),
        )


display(ui, widgets.interactive_output(explore_recordings, w))
# Out:
# ...
# Output()

# %%
_recording = EVALUATION_FOLDER / '03_w17'
fig = plot_recording(
    _recording,
    acoustic_odometry_models=['base'],
    )
savefig(fig, RESULTS_PATH / 'base.png')
# Out:
# 0models [00:00, ?models/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %% [markdown]
# ## Dataset

# %%
_models = ['duration-5', 'base', 'duration-15', 'duration-20']
_recordings = [
    f for f in sorted(EVALUATION_FOLDER.iterdir())
    if f.is_dir() and '_snr' not in f.name
    ]
fig, _ = plot_acoustic_odometry_evaluation(
    recordings=_recordings,
    models=_models,
    delta_seconds=1,
    filter=lambda model, device: 'smartLav+ top' not in device,
    metrics={
        'RPE': 'Mean',
        },
    )
savefig(fig, RESULTS_PATH / 'duration.png')
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %%
_models = ['features-16', 'features-32', 'features-64', 'features-128', 'base']
_recordings = [
    f for f in sorted(EVALUATION_FOLDER.iterdir())
    if f.is_dir() and '_snr' not in f.name
    ]
fig, _ = plot_acoustic_odometry_evaluation(
    recordings=_recordings,
    models=_models,
    delta_seconds=1,
    metrics={
        'RPE': 'Mean',
        },
    filter=lambda model, device: 'smartLav+ top' not in device
    )
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %%
_models = ['segment-10', 'segment-50', 'segment-100', 'base', 'segment-140']
_recordings = [
    f for f in sorted(EVALUATION_FOLDER.iterdir())
    if f.is_dir() and '_snr' not in f.name
    ]
fig, _ = plot_acoustic_odometry_evaluation(
    recordings=_recordings,
    models=_models,
    delta_seconds=1,
    metrics={
        'ATE': 'Mean',
        'RPE': 'Mean',
        },
    filter=lambda model, device: 'smartLav+ top' not in device
    )
savefig(fig, RESULTS_PATH / 'segment.png')
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %%
_models = ['base', 'double-channel']
_recordings = [
    f for f in sorted(EVALUATION_FOLDER.iterdir())
    if f.is_dir() and '_snr' not in f.name
    ]
fig, _ = plot_acoustic_odometry_evaluation(
    recordings=_recordings,
    models=_models,
    delta_seconds=1,
    metrics={
        'ATE': 'Mean',
        'RPE': 'Mean',
        },
    filter=lambda model, device: 'smartLav+ top' not in device
    )
savefig(fig, RESULTS_PATH / 'double-channel.png')
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %%
_models = [
    'only-videomic', 'no-negative-slip', 'base', 'with-laptop', 'all-devices'
    ]
_recordings = [
    f for f in sorted(EVALUATION_FOLDER.iterdir())
    if f.is_dir() and '_snr' not in f.name
    ]
fig, _ = plot_acoustic_odometry_evaluation(
    recordings=_recordings,
    models=_models,
    delta_seconds=1,
    metrics={
        'RPE': 'Mean',
        },
    # filter=lambda model, device: 'smartLav+ top' not in device
    )
savefig(fig, RESULTS_PATH / 'data-devices.png')
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %%
_models = ['base', 'with-noise', 'with-gain', 'all-transforms']
_recordings = [
    f for f in sorted(EVALUATION_FOLDER.iterdir())
    if f.is_dir() and '_snr' not in f.name
    ]
fig, _ = plot_acoustic_odometry_evaluation(
    recordings=_recordings,
    models=_models,
    delta_seconds=1,
    metrics={
        'RPE': 'Mean',
        },
    filter=lambda model, device: 'smartLav+ top' not in device
    )
savefig(fig, RESULTS_PATH / 'data-augmentation.png')
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %% [markdown]
# ## Model task

# %%
_models = [
    'base', 'base-bins-14', 'base-bins-28', 'ordinal-classification',
    'ordinal-classification-bins-14', 'ordinal-classification-bins-28'
    ]
_recordings = [
    f for f in sorted(EVALUATION_FOLDER.iterdir())
    if f.is_dir() and '_snr' not in f.name and '05' in f.name or '06' in f.name
    ]
fig = plt.figure(figsize=(7.5, 8/3))
plot_acoustic_odometry_evaluation(
    recordings=_recordings,
    models=_models,
    delta_seconds=1,
    metrics={
        # 'ATE': 'Mean',
        'RPE': 'Mean',
        },
    filter=lambda model, device: 'smartLav+ top' not in device,
    fig=fig,
    )
savefig(fig, RESULTS_PATH / 'model-task.png')
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %% [markdown]
# ## Model architecture

# %%
_models = [
    'base', 'base-batchnorm', 'ordinal-classification',
    'ordinal-classification-batchnorm'
    ]
_recordings = [
    f for f in sorted(EVALUATION_FOLDER.iterdir())
    if f.is_dir() and '_snr' not in f.name
    ]
fig, _ = plot_acoustic_odometry_evaluation(
    recordings=_recordings,
    models=_models,
    delta_seconds=1,
    metrics={
        'ATE': 'Mean',
        'RPE': 'Mean',
        },
    filter=lambda model, device: 'smartLav+ top' not in device,
    )
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %% [markdown]
# ### Computational cost

# %%
_recordings = [
    f for f in sorted(EVALUATION_FOLDER.iterdir())
    if f.is_dir() and '_snr' not in f.name
    ]
fig = plt.figure(figsize=(7.5, 8))
subfigs = iter(fig.subfigures(3, 1))
_models = ['features-16', 'features-32', 'features-64', 'features-128', 'base']
axs = next(subfigs).subplots(1, 2)
for ax, metric in zip(axs, ['extract', 'predict']):
    _fig, _ = plot_acoustic_odometry_benchmark(
        recordings=_recordings,
        models=_models,
        cost_metric=metric,
        with_device='cpu',
        ax=ax,
        filter=lambda model, device: 'smartLav+ top' not in device,
        )
_fig.legend(
    *axs[0].get_legend_handles_labels(),
    bbox_to_anchor=(1, 0.5),
    loc='center left',
    )
_fig.suptitle('a) Frame features')
_models = ['segment-10', 'segment-50', 'segment-100', 'base', 'segment-140']
axs = next(subfigs).subplots(1, 2)
for ax, with_device in zip(axs, ['cpu', 'cuda']):
    _fig, _ = plot_acoustic_odometry_benchmark(
        recordings=_recordings,
        models=_models,
        cost_metric='predict',
        with_device=with_device,
        filter=lambda model, device: 'smartLav+ top' not in device,
        ax=ax,
        )
_fig.legend(
    *axs[0].get_legend_handles_labels(),
    bbox_to_anchor=(1, 0.5),
    loc='center left',
    )
_fig.suptitle('b) Segment length')
_models = ['base-XXXS', 'base-XXS', 'base-XS', 'base-S', 'base-M', 'base']
axs = next(subfigs).subplots(1, 2)
for ax, with_device in zip(axs, ['cpu', 'cuda']):
    _fig, _ = plot_acoustic_odometry_benchmark(
        recordings=_recordings,
        models=_models,
        cost_metric='predict',
        with_device=with_device,
        filter=lambda model, device: 'smartLav+ top' not in device,
        ax=ax,
        )
_fig.legend(
    *axs[0].get_legend_handles_labels(),
    bbox_to_anchor=(1, 0.5),
    loc='center left',
    )
_fig.suptitle('c) Model size')
extent = fig.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
savefig(
    fig,
    RESULTS_PATH / 'computational-cost.png',
    bbox_inches=extent.expanded(1.25, 1).translated(0.95, 0)
    )
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %% [markdown]
# ### Selected Model

# %%
# _models = ['base', 'selected-v1', 'selected-v2', 'selected-v3']
_models = ['selected-v2']
_recordings = [
    f for f in sorted(EVALUATION_FOLDER.iterdir())
    if f.is_dir() and '_snr' not in f.name
    ]
_ = plot_acoustic_odometry_evaluation(
    recordings=_recordings,
    models=_models,
    delta_seconds=1,
    metrics={
        'ATE': 'Mean',
        'RPE': 'Mean',
        'APE': 'Final',
        'APPE': 'Final',
        },
    # filter=lambda model, device: 'smartLav+ top' not in device
    )
# Out:
# 0recording [00:00, ?recording/s]
# 0model [00:00, ?model/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %%
_model = 'selected-v2'
_device = 'RØDE smartLav+ wheel axis'
_acoustic_odometry_filter = (lambda model, device: _device in device)
_recordings = [
    EVALUATION_FOLDER / r
    for r in ['05_slip', '05_snr2', '05_snr1', '05_snr01', '05_snr001']
    ]
plots = []
for recording in _recordings:
    plots.extend([(odom, f"AO {str(model)} {config['name']}")
                  for odom, config in get_recording_acoustic_odometry(
                      _model, recording, pbars=False, return_config=True
                      )
                  if _acoustic_odometry_filter(str(model), config['name'])])
# All recordings have the same ground truth
fig = plt.figure(figsize=(7.5, 8))
subfigs = fig.subfigures(2, 1)
ax_speed, ax_position = subfigs[0].subplots(1, 2)
ground_truth = get_recording_ground_truth(recording)
ao.plot.odometry_comparison(
    [(ground_truth, 'ground truth')] + plots,
    suptitle='Odometry',
    show_legend=False,
    ax_speed=ax_speed,
    ax_position=ax_position,
    )
ao.plot.evaluation_comparison(
    plots,
    ground_truth,
    suptitle='Evaluation',
    show_legend=False,
    fig=subfigs[1],
    )
handles, labels = ax_position.get_legend_handles_labels()
labels[1:-1] = ['No noise', 'SNR 3 dB', 'SNR 0 dB', 'SNR -10 dB', 'SNR -20 dB']
fig.suptitle(f"Noise effect on selected model with {_device}")
_ = fig.legend(
    handles,
    labels,
    bbox_to_anchor=(0.5, 0),
    loc='upper center',
    )
savefig(fig, RESULTS_PATH / 'noise-effect.png')

# %%
for _model in ['selected-v1', 'selected-v2', 'selected-v3']:
    print(_model)
    for device in ['cpu', 'cuda']:
        benchmark = get_benchmark(_model, with_device=device)
        print(device, benchmark['device']['name'])
        print(
            '; '.join([
                f"{t}: {benchmark['time'][t]['mean'] * 1E-9:0.2e} s"
                for t in ['extract', 'predict', 'total']
                ])
            )
# Out:
# selected-v1
# cpu Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# extract: 7.47e-04 s; predict: 1.68e-03 s; total: 2.48e-03 s
# cuda NVIDIA GeForce RTX 2060
# extract: 5.80e-04 s; predict: 1.20e-03 s; total: 1.99e-03 s
# selected-v2
# cpu Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# extract: 8.12e-04 s; predict: 1.12e-03 s; total: 2.03e-03 s
# cuda NVIDIA GeForce RTX 2060
# extract: 6.59e-04 s; predict: 9.98e-04 s; total: 1.93e-03 s
# selected-v3
# cpu Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz
# extract: 1.74e-03 s; predict: 1.66e-03 s; total: 3.53e-03 s
# cuda NVIDIA GeForce RTX 2060
# extract: 1.39e-03 s; predict: 1.59e-03 s; total: 3.49e-03 s

# %%
_recording = EVALUATION_FOLDER / '05_slip'
fig = plt.figure(figsize=(7.5, 8))
plot_recording(
    _recording,
    acoustic_odometry_models=['selected-v2'],
    acoustic_odometry_filter=(
        lambda model, device: 'smartLav+' in device
        ),
    fig=fig,
    )
savefig(fig, RESULTS_PATH / 'high-slip.png')
# Out:
# 0models [00:00, ?models/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %% [markdown]
# ### Compared to Visual Odometry

# %%
_recording = EVALUATION_FOLDER / '06_w12'
_models = ['selected-v2']
_acoustic_odometry_filter=(
        # lambda model, device: False
        lambda model, device: 'smartLav+ top' in device or 'VideoMic NTG Top' in device
        )
fig = plt.figure(figsize=(7.5, 8))
subfigs = fig.subfigures(2, 1)
_, odom_axes = plot_recording_odometry(
    _recording,
    acoustic_odometry_models=_models,
    visual_odometry_methods=['realsense_T265'],
    wheel_odometry_with_radius=0.1,
    acoustic_odometry_filter=_acoustic_odometry_filter,
    fig=subfigs[0],
    show_legend=False,
    )
odom_axes[0].lines.remove(odom_axes[0].lines[-2])
odom_axes[0].set_ylim(-0.01, 0.06)
subfigs[0].suptitle('Odometry')
_, eval_axes = plot_recording_evaluation(
    _recording,
    acoustic_odometry_models=_models,
    visual_odometry_methods=['realsense_T265'],
    wheel_odometry_with_radius=0.1,
    acoustic_odometry_filter=_acoustic_odometry_filter,
    fig=subfigs[1],
    show_legend=False,
    )
eval_axes[0].set_ylim(0, 0.05)
subfigs[1].suptitle('Evaluation')
fig.suptitle(_recording.name)
fig.legend(
    *odom_axes[1].get_legend_handles_labels(),
    bbox_to_anchor=(0.5, 0),
    loc='upper center'
    )
savefig(fig, RESULTS_PATH / 'other-methods.png')
# Out:
# 0models [00:00, ?models/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]

# %%
_recording = EVALUATION_FOLDER / '07_VO-challenge'
_models = ['selected-v2']
_acoustic_odometry_filter=(
        # lambda model, device: 'VideoMic' in device
        lambda model, device: 'VideoMic NTG Top' in device or 'smartLav+ top' in device
        )
fig = plt.figure(figsize=(7.5, 8))
subfigs = fig.subfigures(2, 1)
_, odom_axes = plot_recording_odometry(
    _recording,
    acoustic_odometry_models=_models,
    visual_odometry_methods=['realsense_T265'],
    wheel_odometry_with_radius=0.1,
    acoustic_odometry_filter=_acoustic_odometry_filter,
    fig=subfigs[0],
    show_legend=False,
    )
odom_axes[0].lines.remove(odom_axes[0].lines[-2])
odom_axes[0].set_ylim(-0.01, 0.04)
subfigs[0].suptitle('Odometry')
_, eval_axes = plot_recording_evaluation(
    _recording,
    acoustic_odometry_models=_models,
    visual_odometry_methods=['realsense_T265'],
    wheel_odometry_with_radius=0.1,
    acoustic_odometry_filter=_acoustic_odometry_filter,
    fig=subfigs[1],
    show_legend=False,
    )
eval_axes[0].set_ylim(0, 0.1)
subfigs[1].suptitle('Evaluation')
fig.suptitle(_recording.name)
fig.legend(
    *odom_axes[1].get_legend_handles_labels(),
    bbox_to_anchor=(0.5, 0),
    loc='upper center'
    )
savefig(fig, RESULTS_PATH / 'VO-challenge.png')
# Out:
# 0models [00:00, ?models/s]
# 0files [00:00, ?files/s]
# 0frames [00:00, ?frames/s]
